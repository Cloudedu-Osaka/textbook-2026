# %% [markdown]
# # 第一回

# %% [markdown]
# ## 入試問題を記述する

# %% [markdown]
# ## 入試問題を解答する

# %% [markdown]
# ### 自然言語と形式言語
#
# * [Natural language - Wikipedia](https://en.wikipedia.org/wiki/Natural_language)
#     * [Pseudocode - Wikipedia](https://en.wikipedia.org/wiki/Pseudocode)
# * [Formal language - Wikipedia](https://en.wikipedia.org/wiki/Formal_language)
#     * [Well-formed formula - Wikipedia](https://en.wikipedia.org/wiki/Well-formed_formula) (Logical/Boolean expression)
#         * [Formula - Wikipedia](https://en.wikipedia.org/wiki/Formula#In_mathematics) (Mathematical expression)
#     * [Programming language - Wikipedia](https://en.wikipedia.org/wiki/Programming_language)

# %% [markdown]
# ### 擬似コード (疑似言語) は形式言語ではない

# %% [markdown]
# ![image.png](attachment:b046ec26-ddb9-4a69-b6ef-73372c39ead6.png)

# %% [markdown]
# ### フローチャートは形式言語
#
# * [Flowchart - Wikipedia](https://en.wikipedia.org/wiki/Flowchart)
#     * ISO 5807:1985 / JIS X 0121:1986

# %% [markdown]
# ![image.png](attachment:84d3dd9f-62f7-43e1-abff-40862dd0a6d1.png)

# %% [markdown]
# ![image.png](attachment:767c07bb-7a27-4e68-8847-5705c8abbff4.png)

# %% [markdown]
# ### DNCL2
#
# 1. 変数
#   - 数、文字列
#   - 配列 (0-base/1-base)
# 2. 文字列
# 3. 代入文
# 4. 算術演算
# 5. 比較演算
# 6. 論理演算
# 7. 関数
#   - 要素数()
#   - 整数()
#   - 乱数()
#   - 表示する()
# 8. 制御文 (条件分岐)
# 9. 制御文 (繰り返し)
# 10. コメント

# %% [markdown]
# ### 量化子
# * [Quantifier (logic) - Wikipedia](https://en.wikipedia.org/wiki/Quantifier_(logic))

# %% [markdown]
# ### 数式認識
# * [Lexical analysis - Wikipedia](https://en.wikipedia.org/wiki/Lexical_analysis)
#     * [Morpheme - Wikipedia](https://en.wikipedia.org/wiki/Morpheme#Morphological_analysis)
# * [Abstract syntax tree - Wikipedia](https://en.wikipedia.org/wiki/Abstract_syntax_tree)
# * [Semantic analysis (linguistics) - Wikipedia](https://en.wikipedia.org/wiki/Semantic_analysis_(linguistics))
#
# * token: identifier, operator, numeral
# * layout: row, frac, sqrt, sup, sub, ~~fenced~~, table/tr/td, stack/sraw/sline
#   * delimiter: fenced
