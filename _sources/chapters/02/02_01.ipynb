# %% [markdown]
# # 第二回: 入試問題を解く (その2) 記述する・解答する

# %% [markdown]
# ```{hint} 前回のまとめ: 卒業を強要するほどPythonは普及していなかった･･･
# * どうしてDNCLによる出題を解答できるのか？
#     - [Program comprehension - Wikipedia](https://en.wikipedia.org/wiki/Program_comprehension)
#         - 分かち書き (tokenize) による読解 (comprehension)
#             - 字句・語彙分析エラー (lexical error) が発生しない
#                 - [Well-formed formula - Wikipedia](https://en.wikipedia.org/wiki/Well-formed_formula)
#         - ノーコードで生成AIは解ける。しかし、形態素解析で学習している (いた)
#             - [Morphological analysis (problem-solving) - Wikipedia](https://en.wikipedia.org/wiki/Morphological_analysis_(problem-solving))
#             - [Byte-pair encoding - Wikipedia](https://en.wikipedia.org/wiki/Byte-pair_encoding) (subword toknization)
# ```

# %% [markdown]
# ```{important} 今回と次回 (5/8 Fri)
# * そもそも、どうして入試問題に解答できるのか？
#     - [ロボットは東大に入れるか。Todai Robot Project](https://21robot.org/index.html)
# * 何故、歴史を遡ろうとしているのか？
# ```

# %% [markdown]
# ## プログラミング教育の推進 (早期化)

# %% [markdown]
# ```{attention} 問題解決能力を育成する
# * [Problem solving - Wikipedia](https://en.wikipedia.org/wiki/Problem_solving)
#     - [Straightedge and compass construction - Wikipedia](https://en.wikipedia.org/wiki/Straightedge_and_compass_construction)
#     - [Computational thinking - Wikipedia](https://en.wikipedia.org/wiki/Computational_thinking)
# ```

# %% [markdown]
# ```{note} 平成29・30・31年の学習指導要領改訂によるプログラミング教育の推進
# * [「教育の情報化に関する手引」について：文部科学省](https://www.mext.go.jp/a_menu/shotou/zyouhou/detail/mext_00117.html)
#     * 第3章 プログラミング教育の推進
#         - プログラミング的指向
#             - (design) (コンピュータに) 自分が意図する一連の活動を実現するために、
#             - (abstraction) どのような動きの組み合わせが必要であり、
#             - (coding) 一つ一つの動きに対応した記号を、どのように組み合わせたらいいのか、
#             - (debugging) 記号の組み合わせをどのように改善していけば、より意図した活動に近づくのか
# ```

# %% [markdown]
# ```{seealso}
# * 文部科学省
#     - 教育の情報化の推進
#         - 高等学校情報科 (各学科に共通する教材)
#             - [高等学校情報科「情報Ⅱ」教員研修用教材(本編)：文部科学省](https://www.mext.go.jp/a_menu/shotou/zyouhou/detail/mext_00742.html)
# ```

# %% [markdown]
# ## そもそも、どうして入試問題に解答できるのか？

# %% [markdown]
# ```{note} 何故、作図問題を解けるのか？
# * 初等・中等教育 (算数・数学) でどのような能力を育成してきたか？
#     - 作図能力
#     - 作図の記述能力
#         * 定義、公準・公理、命題
#     - 作図の推論能力
#         * 仮定、仮説 (conjecture)、証明
#     - 作図の数式による記述能力
#     - 作図の論理による推論能力
# ```

# %% [markdown]
# ```{attention} 情報・プログラミング以外の入試問題を記述する
#
# ```
