# %% [markdown]
# # 第一回: 入試問題を解く (その1) 記述する

# %% [markdown]
# ```{hint}
# * 次の例題の出典は？
# ```

# %%
using Pkg
# Pkg.activate("../../../julia/GeoGebra.jl")
Pkg.activate()
Pkg.instantiate()
# Pkg.precompile()
using GeoGebra

# %%
using GeoGebra

# %%
inject_applet()

# %%
@ggb :api getVersion()

# %% [markdown]
# ### 1.13.1 作図

# %%
using SymPyPythonCall

# %%
@syms x, a, p, q

# %%
@syms f(), g(), h()

# %%
@syms g_1(), g_2(), g_3()

# %%
@ggb a=Slider(-2π, 2π)

# %%
@ggb g_1 = sin(x+a)

# %%
@ggb g_2 = sin(x+2a)

# %%
@ggb g_3 = sin(x+3a)

# %%
@ggb g = g_1(x) + g_2(x) + g_3(x)

# %%
@ggb g_1(x)+g_2(x)

# %%
@ggb g_2(x)+g_3(x)

# %%
@ggb g_3(x)+g_1(x)

# %% [markdown]
# ## 1.13.2 出題: 数学Ⅱ, 数学B, 数学C の 第2問

# %% [markdown]
# ![image.png](attachment:7cccd561-d7e3-4de1-8891-5d7b0e053fcd.png)

# %% [markdown]
# ![image.png](attachment:ed938201-e8d0-466f-94d5-9732fc341e1f.png)

# %% [markdown]
# ![image.png](attachment:e1b36a9d-32f6-4db3-9869-1ee3baf56aaf.png)

# %% [markdown]
# ![image.png](attachment:1685c6c2-46c4-4303-8402-427693ed8740.png)

# %% [markdown]
# ![image.png](attachment:791bd73f-ea70-46b3-b751-45bfd4611afe.png)

# %% [markdown]
# $$g(x) = \sin(x+a) + \sin(x+2a) + \sin(x+3a)$$

# %% [markdown]
# $$g(x) = p \sin(x+q)$$

# %% [markdown]
# ### 1.13.2 解答

# %%
@ggb "(2cos(a)+1)"*g_2(x)
